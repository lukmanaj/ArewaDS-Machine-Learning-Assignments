# %% [markdown]
# # Intro to Sklearn Practice

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model, model_selection

# %% [markdown]
# We are looking at the diabetes dataset to practice using the sklearn library
#
#
# The built-in diabetes dataset includes 442 samples of data around diabetes, with 10 feature variables, some of which include:
#
# age: age in years
# bmi: body mass index
# bp: average blood pressure
# s1 tc: T-Cells (a type of white blood cells)
#
# ✅ This dataset includes the concept of 'sex' as a feature variable important to research around diabetes. Many medical datasets include this type of binary classification. Think a bit about how categorizations such as this might exclude certain parts of a population from treatments.

# %%
# loading the in-built diabetes datasets
X,y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %% [markdown]
# The input return_X_y=True signals that X will be a data matrix, and y will be the regression target.

# %% [markdown]
# Next, we select a portion of this dataset to plot by arranging it into a new array using numpy's newaxis function.
#
# We are going to use linear regression to generate a line between values in this data, according to a pattern it determines.

# %%
X = X[:,np.newaxis,2]

# %%
X.shape
# Out:
# (442, 1)

# %% [markdown]
# Data is ready to be plotted, yay!!!
#
# Let's see if a machine can help determine a logical split between the numbers in this dataset. To do this, we need to split both the data (X) and the target (y) into test and training sets. Test and training sets will help in making sure the model doesnt overfit.
#
# Scikit-learn has a straightforward way to do this; you can split your test data at a given point.

# %%
X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,test_size=0.3)

# %% [markdown]
# Next is to train the model!
# We load up the linear regression model and train it with your X and y training sets using model.fit():

# %%
model = linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# We then create a prediction using test data, using the function predict(). This will be used to draw the line between data groups

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# It's always nice to show the data in a plot.
#  Matplotlib is a very useful tool for this task. We create a scatterplot of all the X and y test data, and use the prediction to draw a line in the most appropriate place, between the model's data groupings.

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %% [markdown]
# Think a bit about what's going on here. A straight line is running through many small dots of data, but what is it doing exactly? Can you see how you should be able to use this line to predict where a new, unseen data point should fit in relationship to the plot's y axis? Try to put into words the practical use of this model.
#
# --in my own words-- With the line, we can just trace the value of the scaled BMI to predict the disease progression. That's the point. Amazing!!!
#
# Yay, we built our first linear regression model with ArewaDS, created a prediction with it, and displayed it in a plot!

# %% [markdown]
# # Challenge
#
# Plot a different variable from this dataset. Hint: edit this line: X = X[:, np.newaxis, 2]. Given this dataset's target, what are you able to discover about the progression of diabetes as a disease?

# %%
# loading the in-built diabetes datasets again, in Jupyter notebook, the order of running the cells matter!
X,y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %% [markdown]
# To plot a different variable, I'll change the number here to a different number, let's say 4

# %%
X = X[:,np.newaxis,4]

# %%
# now the shape
X.shape
# Out:
# (442, 1)

# %% [markdown]
# We're on track
#
# We can now split and train

# %%
X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,test_size=0.3)

# %%
model = linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
# finally, the plot
plt.scatter(X_test,y_test,color='black')
plt.plot(X_test,y_pred,color='blue',linewidth=3)
plt.xlabel('Not sure yet')
plt.ylabel('Disease Progression')
plt.title('Graph of Disease Progression against new feature')
plt.show()

# %% [markdown]
# ## Checking Out Linnerud for Assignment

# %%
linnerud = datasets.load_linnerud(as_frame=True)

# %%
linnerud.target_filename
# Out:
# 'linnerud_physiological.csv'

# %%
linnerud.target_names
# Out:
# ['Weight', 'Waist', 'Pulse']

# %%
linnerud.feature_names
# Out:
# ['Chins', 'Situps', 'Jumps']
