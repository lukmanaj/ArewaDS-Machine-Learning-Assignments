# %% [markdown]
# # Visualize some more Time Series
#
# Instructions
#
# You've begun to learn about Time Series Forecasting by looking at the type of data that requires this special modeling. You've visualized some data around energy. Now, look around for some other data that would benefit from Time Series Forecasting. Find three examples (try Kaggle and Azure Open Datasets) and create a notebook to visualize them. Notate any special characteristics they have (seasonality, abrupt changes, or other trends) in the notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.datasets import get_rdataset
import matplotlib.dates as mdates

# Load the AirPassengers dataset from statsmodels
data = get_rdataset('AirPassengers').data

# Convert the index to a datetime format
data.index = pd.to_datetime(data['time'])

# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['value'])
plt.title("Airline Passengers over Time")
plt.xlabel("Year")
plt.ylabel("Number of Passengers")
plt.grid(True)

# Format the x-axis tick labels to show only the years
years_fmt = mdates.DateFormatter('%Y')
plt.gca().xaxis.set_major_formatter(years_fmt)

plt.show()

# %% [markdown]
# The trend in this dataset is an increase in the number of passengers as the years progress. Of course, people began working more in this global village and it is expected that the need for movement in this fast-paced world will increase as the economy booms.
