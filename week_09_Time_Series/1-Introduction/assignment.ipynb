# %% [markdown]
# # Visualize some more Time Series
#
# Instructions
#
# You've begun to learn about Time Series Forecasting by looking at the type of data that requires this special modeling. You've visualized some data around energy. Now, look around for some other data that would benefit from Time Series Forecasting. Find three examples (try Kaggle and Azure Open Datasets) and create a notebook to visualize them. Notate any special characteristics they have (seasonality, abrupt changes, or other trends) in the notebook.

# %% [markdown]
# ## Book Sales Dataset

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset
books = pd.read_csv('../kaggle_datasets/book_sales.csv',index_col='Date',parse_dates= ['Date']).drop('Paperback',axis=1)
books.head()
# Out:
#             Hardcover
# Date
# 2000-04-01        139
# 2000-04-02        128
# 2000-04-03        172
# 2000-04-04        139
# 2000-04-05        191

# %% [markdown]
# Add time-step feature

# %%
books['Time'] = np.arange(len(books.index))

books.head()
# Out:
#             Hardcover  Time
# Date
# 2000-04-01        139     0
# 2000-04-02        128     1
# 2000-04-03        172     2
# 2000-04-04        139     3
# 2000-04-05        191     4

# %% [markdown]
# Plot time plot

# %%
plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
# %config InlineBackend.figure_format = 'retina'


fig, ax = plt.subplots()
ax.plot('Time', 'Hardcover', data= books, color='0.75')
ax = sns.regplot(x='Time', y='Hardcover', data= books, ci=None, scatter_kws=dict(color='0.25'))
ax.set_title('Time Plot of Hardcover Sales')
# Out:
# /tmp/ipykernel_753/4286290661.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
# Text(0.5, 1.0, 'Time Plot of Hardcover Sales')

# %% [markdown]
# The general trend is that the number of hardcover sales increases with the time.

# %%
# Trying another method
books['Hardcover'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# The troughs (low sales) could be due to holidays or some other factors

# %% [markdown]
# # Flu trends Datasets

# %%
flu = pd.read_csv('../kaggle_datasets/flu-trends.csv',index_col= 'Week')
len(flu)
# Out:
# 366

# %% [markdown]
# Will take this easy. Just plotting the flu visits to see the time trend

# %%
flu['FluVisits'].plot()
plt.title('Time series of Total Flu Visits')
plt.show()

# %% [markdown]
# It can be seen that there are peaks that correspond to seasons when flu visits increase, possibly due to flu outbreaks.

# %% [markdown]
# # Trig Dataset

# %%
trig = pd.read_csv('../kaggle_datasets/trig.csv',index_col = 'date',parse_dates= ['date']).drop(['Unnamed: 0','language','article'],axis=1)
trig.head()
# Out:
#             views
# date
# 2007-12-10   2573
# 2007-12-11   2443
# 2007-12-12   2392
# 2007-12-13   2350
# 2007-12-14   1856

# %%
trig['Time'] = np.arange(len(trig.index))
trig.head()
# Out:
#             views  Time
# date
# 2007-12-10   2573     0
# 2007-12-11   2443     1
# 2007-12-12   2392     2
# 2007-12-13   2350     3
# 2007-12-14   1856     4

# %%
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
# %config InlineBackend.figure_format = 'retina'


fig, ax = plt.subplots()
ax.plot('Time', 'views', data= trig, color='0.75')
ax = sns.regplot(x='Time', y='views', data= trig, ci=None, scatter_kws=dict(color='0.25'))
ax.set_title('Time Article Views')
# Out:
# Text(0.5, 1.0, 'Time Article Views')

# %% [markdown]
# Looking at it another way

# %%
trig['views'].plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# There are some outliers with high views which may can not be explained fully by looking at just time.
# The trend is that the views did not significantly increase over the years and the line shows that the views actually decreased over time overall.
